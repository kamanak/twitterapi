# %% [markdown]
# # Twitter API CALL

# %%
import os
import tweepy as tw
import pandas as pd
import pprint
import pymongo as pym

consumer_key= 'UnNiqEe6giHuHNr1ByDuANhOX'
consumer_secret= 'nt9oJansWdwbbwvU93r5MuaQW8yUwUWGXPYmtkrrLCNO1MSdJj'
access_token= '1533729531252850689-bR9tfRCw6qUlrElxGDxtXZTCBdDDs4'
access_token_secret= '89DuX5hZLLLX30UtT0g8LVW5BSYzAsrACUYGCb2NzYBJi'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# username_tweets = tw.Cursor(api.user_timeline, q="@elonmusk", tweet_mode='extended').items(200)
new_tweets = tw.Cursor(api.user_timeline, screen_name="elonmusk", tweet_mode='extended').items(200)

# %%
list = []
for tweet in new_tweets:
    text = tweet._json["full_text"]

    refined_tweet = {
                    'user_name':tweet.user.name,
                    'user_id':tweet.user.id,
                    'tweet_id':tweet.id,
                    'text' : text,
                    'retweet_count' : tweet.retweet_count,
                    'created_at':tweet.created_at
                    
        
                    }
    
    list.append(refined_tweet)

# %%
list
# Out:
# [{'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533992088206921728,
#   'text': '@PPathole It will be our best product ever imo',
#   'retweet_count': 1969,
#   'created_at': datetime.datetime(2022, 6, 7, 1, 59, 48, tzinfo=datetime.timezone.utc)},
#  {'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533857698575310848,
#   'text': 'What resolution is life in, 8k? – SJM',
#   'retweet_count': 5794,
#   'created_at': datetime.datetime(2022, 6, 6, 17, 5, 47, tzinfo=datetime.timezone.utc)},
#  {'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533839270976204801,
#   'text': '@realMeetKevin Correct',
#   'retweet_count': 1668,
#   'created_at': datetime.datetime(2022, 6, 6, 15, 52, 34, tzinfo=datetime.timezone.utc)},
#  {'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533834416656486401,
#   'text': '@realchrisrufo @Liv_Boeree There are still some great journalists at WaPo, but the trend is super bad',
# ...

# %%
df = pd.DataFrame(list)

# %%
df
# Out:
#      user_name   user_id             tweet_id  \
# 0    Elon Musk  44196397  1533992088206921728
# 1    Elon Musk  44196397  1533857698575310848
# 2    Elon Musk  44196397  1533839270976204801
# 3    Elon Musk  44196397  1533834416656486401
# 4    Elon Musk  44196397  1533834190600347648
# ..         ...       ...                  ...
# 195  Elon Musk  44196397  1530380264966434823
# 196  Elon Musk  44196397  1530379867111542784
# 197  Elon Musk  44196397  1530379410645319680
# 198  Elon Musk  44196397  1530358187706179585
# 199  Elon Musk  44196397  1530355592564551682
#
#                                                   text  retweet_count  \
# 0       @PPathole It will be our best product ever imo           1821
# 1                What resolution is life in, 8k? – SJM           5574
# 2                               @realMeetKevin Correct           1640
# 3    @realchrisrufo @Liv_Boeree There are still som...            846
# ...

# %%
type(df['created_at'][0])
df['created_at']=df['created_at'].dt.tz_localize(None)
# df['created_at'] = pd.to_datetime(df['created_at']).dt.date

# %%
df
# Out:
#      user_name   user_id             tweet_id  \
# 0    Elon Musk  44196397  1533992088206921728
# 1    Elon Musk  44196397  1533857698575310848
# 2    Elon Musk  44196397  1533839270976204801
# 3    Elon Musk  44196397  1533834416656486401
# 4    Elon Musk  44196397  1533834190600347648
# ..         ...       ...                  ...
# 195  Elon Musk  44196397  1530380264966434823
# 196  Elon Musk  44196397  1530379867111542784
# 197  Elon Musk  44196397  1530379410645319680
# 198  Elon Musk  44196397  1530358187706179585
# 199  Elon Musk  44196397  1530355592564551682
#
#                                                   text  retweet_count  \
# 0       @PPathole It will be our best product ever imo           1821
# 1                What resolution is life in, 8k? – SJM           5574
# 2                               @realMeetKevin Correct           1640
# 3    @realchrisrufo @Liv_Boeree There are still som...            846
# ...

# %%
# date_time = curDT.strftime("%m/%d/%Y, %H:%M:%S")
df['created_at'] = df['created_at'].dt.strftime("%m/%d/%Y")

# %%
df['tweet_date'] = df['created_at']

# %%
df = df.drop(['created_at'], axis=1)
df
# Out:
#      user_name   user_id             tweet_id  \
# 0    Elon Musk  44196397  1533992088206921728
# 1    Elon Musk  44196397  1533857698575310848
# 2    Elon Musk  44196397  1533839270976204801
# 3    Elon Musk  44196397  1533834416656486401
# 4    Elon Musk  44196397  1533834190600347648
# ..         ...       ...                  ...
# 195  Elon Musk  44196397  1530380264966434823
# 196  Elon Musk  44196397  1530379867111542784
# 197  Elon Musk  44196397  1530379410645319680
# 198  Elon Musk  44196397  1530358187706179585
# 199  Elon Musk  44196397  1530355592564551682
#
#                                                   text  retweet_count  \
# 0       @PPathole It will be our best product ever imo           1821
# 1                What resolution is life in, 8k? – SJM           5574
# 2                               @realMeetKevin Correct           1640
# 3    @realchrisrufo @Liv_Boeree There are still som...            846
# ...

# %%
df.describe()
# Out:
#           user_id      tweet_id  retweet_count
# count       200.0  2.000000e+02     200.000000
# mean   44196397.0  1.532071e+18    5073.630000
# std           0.0  1.028659e+15   15207.058691
# min    44196397.0  1.530356e+18      65.000000
# 25%    44196397.0  1.531307e+18     277.000000
# 50%    44196397.0  1.531872e+18     693.000000
# 75%    44196397.0  1.533106e+18    2853.250000
# max    44196397.0  1.533992e+18  145720.000000

# %%
df.to_csv('tweet_data.csv')

# %%
df_dict = df.to_dict('records')
df_dict
# Out:
# [{'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533992088206921728,
#   'text': '@PPathole It will be our best product ever imo',
#   'retweet_count': 1821,
#   'tweet_date': '06/07/2022'},
#  {'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533857698575310848,
#   'text': 'What resolution is life in, 8k? – SJM',
#   'retweet_count': 5574,
#   'tweet_date': '06/06/2022'},
#  {'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533839270976204801,
#   'text': '@realMeetKevin Correct',
#   'retweet_count': 1640,
#   'tweet_date': '06/06/2022'},
#  {'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533834416656486401,
#   'text': '@realchrisrufo @Liv_Boeree There are still some great journalists at WaPo, but the trend is super bad',
#   'retweet_count': 846,
#   'tweet_date': '06/06/2022'},
#  {'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533834190600347648,
# ...

# %%
df_dict[:2]
# Out:
# [{'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533992088206921728,
#   'text': '@PPathole It will be our best product ever imo',
#   'retweet_count': 1331,
#   'tweet_date': '06/07/2022'},
#  {'user_name': 'Elon Musk',
#   'user_id': 44196397,
#   'tweet_id': 1533857698575310848,
#   'text': 'What resolution is life in, 8k? – SJM',
#   'retweet_count': 5170,
#   'tweet_date': '06/06/2022'}]

# %% [markdown]
# # Inserting ito mongodb compass

# %%
#Making Mongo DB connection
client = pym.MongoClient('mongodb://localhost:27017')
#Creating database
db = client['twitter_data']
#Creating collection
col = db['raw_tweets']

# %%
#Inserting it into a database
col.insert_many(df_dict)

# %% [markdown]
# # Inserting into mongodb cluster

# %%
#Making Mongo DB connection
client = pym.MongoClient('mongodb+srv://kamana:KALUdallu99@cluster0.qqveddo.mongodb.net/?retryWrites=true&w=majority')
#Creating database
db = client['twitter_data']
#Creating collection
col = db['raw_tweets']

# %%
col.insert_many(df_dict)
