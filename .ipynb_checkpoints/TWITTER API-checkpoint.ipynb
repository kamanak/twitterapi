# %%
import os
import tweepy as tw
import pandas as pd
import pprint

# %%
consumer_key= 'UnNiqEe6giHuHNr1ByDuANhOX'
consumer_secret= 'nt9oJansWdwbbwvU93r5MuaQW8yUwUWGXPYmtkrrLCNO1MSdJj'
access_token= '1533729531252850689-bR9tfRCw6qUlrElxGDxtXZTCBdDDs4'
access_token_secret= '89DuX5hZLLLX30UtT0g8LVW5BSYzAsrACUYGCb2NzYBJi'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# cursor = tw.Cursor(api.user_timeline,id ="kamana",tweet_mode= 'extended').items(1)

# %%
# cursor

# %%
# for i in cursor:
#     print(i)

# %%
# number_of_tweets = 200
# tweets =[]
# likes =[]
# time = []
# for i in tw.Cursor(api.user_timeline, id ="2244994945",tweet_mode= 'extended').items(number_of_tweets):
#     tweets.append(i.full_text)
#     likes.append(i.favorite_count)
#     time.append(i.created_at)

# %%
user = 'veritasium'
limit = 100

# %%
tweets = api.user_timeline(screen_name=user,count=limit,tweet_mode ='extended')

# %%
for tweet in tweets:
     print(tweet)
# Out:
# Status(_api=<tweepy.api.API object at 0x0000020A6C88BA00>, _json={'created_at': 'Sun May 01 03:56:24 +0000 2022', 'id': 1520613080698605568, 'id_str': '1520613080698605568', 'full_text': '@christos_markou I can upload an .srt file if you email it to me…', 'truncated': False, 'display_text_range': [17, 65], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'christos_markou', 'name': 'christos', 'id': 112427136, 'id_str': '112427136', 'indices': [0, 16]}], 'urls': []}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': 1520392480738394112, 'in_reply_to_status_id_str': '1520392480738394112', 'in_reply_to_user_id': 112427136, 'in_reply_to_user_id_str': '112427136', 'in_reply_to_screen_name': 'christos_markou', 'user': {'id': 168987151, 'id_str': '168987151', 'name': 'Derek Muller', 'screen_name': 'veritasium', 'location': 'Los Angeles', 'description': 'I make Youtube videos about science. Ph
# ...

# %%
# for tweet in tweets:
#     print(tweet.id)
id = []
tw =[]
likes =[]
time = []
for tweet in tweets:
    id.append(tweet.id)
    tw.append(tweet.full_text)
    time.append(tweet.created_at)

# %%
my_dict = {'tw':'tw','time':'time'}
df = pd.DataFrame([my_dict])

# %%
df
# Out:
#    tw  time
# 0  tw  time

# %%
print(tweet)
# Out:
# Status(_api=<tweepy.api.API object at 0x0000020A6C88BA00>, _json={'created_at': 'Tue Jul 06 01:43:59 +0000 2021', 'id': 1412225784488419330, 'id_str': '1412225784488419330', 'full_text': "@alexjohnward @nano @neiltyson I have to know the specific claim before I'm willing to bet.", 'truncated': False, 'display_text_range': [31, 91], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'alexjohnward', 'name': 'Nano is green money🥦🥬 Alex Ward', 'id': 468252383, 'id_str': '468252383', 'indices': [0, 13]}, {'screen_name': 'nano', 'name': 'Nano', 'id': 704476690139885568, 'id_str': '704476690139885568', 'indices': [14, 19]}, {'screen_name': 'neiltyson', 'name': 'Neil deGrasse Tyson', 'id': 19725644, 'id_str': '19725644', 'indices': [20, 30]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': 1412199242697871382, 'in_reply_to_status_id_str': '1412199242697871382', 'in_reply_to_user_id': 468252
# ...

# %%
tweet =pd.to_json("tweets")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [113], in <cell line: 1>()
# ----> 1 tweet =pd.to_json("tweets")
#
# File ~\anaconda3\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'to_json'

# %%
import os
import tweepy as tw
import pandas as pd
import pprint

consumer_key= 'UnNiqEe6giHuHNr1ByDuANhOX'
consumer_secret= 'nt9oJansWdwbbwvU93r5MuaQW8yUwUWGXPYmtkrrLCNO1MSdJj'
access_token= '1533729531252850689-bR9tfRCw6qUlrElxGDxtXZTCBdDDs4'
access_token_secret= '89DuX5hZLLLX30UtT0g8LVW5BSYzAsrACUYGCb2NzYBJi'

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
username_tweets = tw.Cursor(api.user_timeline, q="@elonmusk", tweet_mode='extended').items(200)

# %%
list = []
for tweet in new_tweets:
    text = tweet._json["full_text"]

    refined_tweet = {'text' : text,
                    'favorite_count' : tweet.favorute_count,
                    'retweet_count' : tweet.retweet_count,
                    'created_at' : tweet.created_at}
    
    list.append(refined_tweet)
